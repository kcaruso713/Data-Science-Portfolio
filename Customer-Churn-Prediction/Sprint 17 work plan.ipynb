# %% [markdown]
# <div style="border: 5px solid purple; padding: 10px; margin: 5px">
# <b> Svetlana's comment  </b>
#
#
# Hi, it's Svetlana.
#
#
# Thank you for submitting such a great plan! It has everything you need, so you can move on to the code part! :)
#
#
#
# Answers to your questions:
#
#
#
#
# > - What metric should be prioritized when evaluating the churn model: accuracy, recall, F1 score, ROC-AUC, or another metric?
#
# If AUCROC is the main metric, then you should rely on it first of all. In the task description, the requirement clearly specifies the metric.
#
#
# > - How should the class imbalance between customers who stayed and customers who churned be addressed?
#
# This is a question to you. Should we handle it? If yes, how? Feel free to refer to the supervise learning sprint if needed.
#
#
# > - Are there any buisness requirements for the minimum acceptable model performance?
#
#
# If it is not stated, then no. In real life, there may be different requirements, but we usually have an opportunity to get more information about business, data or clients. However, sometimes we must work with the provided data, even if it seems incomplete or insufficient.
#
#
# > - Which customer characteristics and services are expected to be the strongest predictors of churn?
#
#
# We never know until we train a model. We can assume though, but until we see the results, we still cannot make any conclusions.
#
# </div>

# %%
import pandas as pd

contract = pd.read_csv('/datasets/final_provider/contract.csv')
personal = pd.read_csv('/datasets/final_provider/personal.csv')
internet = pd.read_csv('/datasets/final_provider/internet.csv')
phone = pd.read_csv('/datasets/final_provider/phone.csv')

# %%
contract.head()
# Out:
#    customerID   BeginDate              EndDate            Type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# 4  9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check           53.85       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65

# %%
print('Contract:', contract.shape)
print('Personal:', personal.shape)
print('Internet:', internet.shape)
print('Phone:', phone.shape)
# Out:
# Contract: (7043, 8)
# Personal: (7043, 5)
# Internet: (5517, 8)
# Phone: (6361, 2)

# %%
contract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.3+ KB

# %%
type(contract)
# Out:
# pandas.core.frame.DataFrame

# %%
contract.isna().sum()
# Out:
# customerID          0
# BeginDate           0
# EndDate             0
# Type                0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# dtype: int64

# %%
contract['EndDate'].isna().value_counts(normalize=True)
# Out:
# False    1.0
# Name: EndDate, dtype: float64

# %% [markdown]
# # Interconnect Project - Proposed Work Plan
#
# ## Project goal:
#
# Develop a machine-learning model that predicts whether a customer is likely to leave Interconnect's services.

# %% [markdown]
# # Clarifying questions
# - What metric should be prioritized when evaluating the churn model: accuracy, recall, F1 score, ROC-AUC, or another metric?
# - How should the class imbalance between customers who stayed and customers who churned be addressed?
# - Are there any buisness requirements for the minimum acceptable model performance?
# - Which customer characteristics and services are expected to be the strongest predictors of churn?

# %% [markdown]
# ## 1. Load, combine and inspect the data
# Load the four datasets and merge them using the customer ID.Examine the structure, data types, missing values, duplicates, and class distribution.

# %% [markdown]
# ## 2. Pre-process the data
# Standardize column names and correct data types, including dates and total charges. Perform exploratory data analysis to understand customer characteristics and identify patterns associated with churn.

# %% [markdown]
# ## 3. Engineer features and prepare the data for modeling.
# Create the churn target from the contract end date, extract useful information from dates, and encode categorical variables. Split the data into training, validation, and test sets and address the class imbalance using the training data.

# %% [markdown]
# ## 4. Train and evaluate classification models.
# Train several models, compare their performance using appropriate evaluation metrics, and tune the best-performing models.

# %% [markdown]
# ## 5. Select the final model and provide conclusions.
# Choose the model that best meets the project requirements and summarize the factors associated with customer churn. Provide recommendations for how Interconnect could use the model to identify customers at risk of leaving.
